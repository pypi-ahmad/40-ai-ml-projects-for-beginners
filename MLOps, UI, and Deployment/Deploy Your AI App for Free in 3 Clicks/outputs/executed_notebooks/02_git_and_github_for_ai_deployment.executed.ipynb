# %% [markdown]
# # 02 - Git and GitHub for AI Deployment
#
# This chapter teaches Git and GitHub from scratch with deployment context.

# %% [markdown]
# ## Section 1: Git Fundamentals
#
# ### Definition
# Git is distributed version control system that tracks file changes over time.
#
# ### Theory
# Every commit stores snapshot of project state and metadata (author, timestamp, message).
#
# ### Motivation
# Deployment platforms pull exact commit state, not loose local files.
#
# ### Real-World Examples
# - Roll back broken release to previous commit.
# - Compare two model-serving implementations.
#
# ### Visual Explanation
# ![Git Workflow](../outputs/figures/git-workflow.png)
#
# ### Best Practices
# - Use meaningful commit messages.
# - Commit frequently in small logical units.
#
# ### Common Mistakes
# - One huge commit after days of work.
# - Ambiguous messages like `update`.

# %%
from pathlib import Path
import subprocess
import tempfile

demo_dir = Path(tempfile.mkdtemp(prefix="git_demo_"))
print("Demo repo:", demo_dir)

commands = [
    ["git", "init"],
    ["git", "config", "user.name", "demo-user"],
    ["git", "config", "user.email", "demo@example.com"],
]
for cmd in commands:
    out = subprocess.run(cmd, cwd=demo_dir, capture_output=True, text=True, check=False)
    print("$", " ".join(cmd))
    print((out.stdout or out.stderr).strip())

(demo_dir / "README.md").write_text("# Demo Repo\n")
subprocess.run(["git", "add", "README.md"], cwd=demo_dir, check=False)
subprocess.run(["git", "commit", "-m", "feat: add README"], cwd=demo_dir, check=False)

log = subprocess.run(["git", "log", "--oneline", "-n", "1"], cwd=demo_dir, capture_output=True, text=True, check=False)
print("Latest commit:", log.stdout.strip())
# Out:
# Demo repo: /tmp/git_demo_5ylikq9n
# $ git init
# Initialized empty Git repository in /tmp/git_demo_5ylikq9n/.git/
# $ git config user.name demo-user
#
# $ git config user.email demo@example.com
#
# [main (root-commit) 530edd4] feat: add README
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md
# Latest commit: 530edd4 feat: add README

# %% [markdown]
# ## Section 2: Core Git Terms
#
# ### Definition and Motivation
# - **Repository:** project folder tracked by Git.
# - **Commit:** saved checkpoint.
# - **Branch:** independent line of development.
# - **Push:** upload commits to remote.
# - **Pull:** sync remote changes locally.
# - **Main branch:** default integration branch for releases.
#
# ### Theory
# Branching allows feature work without destabilizing deployment branch.
#
# ### Real-World Example
# Build feature in `feature/deploy-monitoring`, then merge to `main` only after tests pass.
#
# ### Code Explanation
# Next cell prints branch state from current project, if available.
#
# ### Best Practices
# - Protect `main` with CI checks.
# - Keep branch names task-scoped.
#
# ### Common Mistakes
# - Working directly on main for risky changes.
# - Force-pushing shared branches.

# %%
from pathlib import Path
import subprocess

root = Path.cwd()
if not (root / ".git").exists() and (root.parent / ".git").exists():
    root = root.parent

status = subprocess.run(["git", "status", "--short"], cwd=root, capture_output=True, text=True, check=False)
branch = subprocess.run(["git", "rev-parse", "--abbrev-ref", "HEAD"], cwd=root, capture_output=True, text=True, check=False)

print("Branch:", branch.stdout.strip() or "unavailable")
print("Status output:\n", status.stdout.strip() or "(clean or unavailable)")
# Out:
# Branch: main
# Status output:
#  M .github/workflows/ci.yml
#  M .streamlit/secrets.toml.example
#  M README.md
#  M docs/deployment_checklist.md
#  M docs/monitoring_guide.md
#  M docs/platform_comparison.md
#  M docs/troubleshooting_playbook.md
#  M notebooks/01_deployment_foundations_and_mlops.ipynb
#  M notebooks/02_git_and_github_for_ai_deployment.ipynb
#  M notebooks/03_building_production_deployment_candidate.ipynb
#  M notebooks/04_streamlit_cloud_real_deployment.ipynb
#  M notebooks/05_troubleshooting_monitoring_and_optimization.ipynb
#  M notebooks/06_security_platform_comparison_and_ops_checklists.ipynb
#  M outputs/deployment/deployment_evidence.json
#  M outputs/deployment/local_validation_evidence.json
#  M outputs/executed_notebooks/01_deployment_foundations_and_mlops.executed.ipynb
#  M outputs/executed_notebooks/02_git_and_github_for_ai_deployment.executed.ipynb
#  M outputs/executed_notebooks/03_building_production_deployment_candidate.executed.ipynb
#  M outputs/executed_notebooks/04_streamlit_cloud_real_deployment.executed.ipynb
#  M outputs/executed_notebooks/05_troubleshooting_monitoring_and_optimization.executed.ipynb
#  M outputs/executed_notebooks/06_security_platform_comparison_and_ops_checklists.executed.ipynb
#  M outputs/metrics/runtime_benchmark.json
#  M outputs/metrics/runtime_snapshot.json
#  M pyproject.toml
#  M requirements-dev.txt
#  M requirements.txt
#  M scripts/benchmark_runtime.py
#  M scripts/build_notebooks.py
#  M scripts/capture_evidence.py
#  M scripts/execute_notebooks.py
#  M scripts/validate_project.py
#  M streamlit_app/components/sidebar.py
#  M streamlit_app/pages/classification.py
#  M streamlit_app/pages/sentiment.py
#  M streamlit_app/pages/summarization.py
#  M streamlit_app/pages/translation.py
#  M streamlit_app/utils/caching.py
#  M streamlit_app/utils/helpers.py
#  M streamlit_app/utils/models.py
#  M templates/deployment_checklist_template.md
#  M tests/test_helpers.py
#  M uv.lock
# ?? .dockerignore
# ?? .env.example
# ?? Dockerfile.api
# ?? FINAL_PROJECT_VERIFICATION_REPORT.md
# ?? api_app.py
# ?? data/
# ?? docs/api_security_notes.md
# ?? docs/api_testing_and_validation.md
# ?? docs/fastapi_api_guide.md
# ?? ml_api/
# ?? notebooks/api/
# ?? outputs/api_benchmarks/
# ?? outputs/api_model/
# ?? outputs/figures/fastapi-architecture.png
# ?? outputs/figures/fastapi-request-flow.png
# ?? outputs/metrics/fastapi_runtime_benchmark.json
# ?? requirements-api.txt
# ?? requirements-automl.txt
# ?? scripts/benchmark_api_runtime.py
# ?? scripts/build_api_notebooks.py
# ?? scripts/generate_ames_snapshot.py
# ?? scripts/generate_api_diagrams.py
# ?? scripts/train_api_models.py
# ?? scripts/validate_api_project.py
# ?? streamlit_app/utils/config.py
# ?? tests/api/
# ?? tests/test_config.py

# %% [markdown]
# ## Section 3: GitHub Fundamentals
#
# ### Definition
# GitHub is remote hosting platform for Git repositories.
#
# ### Theory
# Deployment platforms integrate with GitHub webhooks and build from selected branch.
#
# ### Motivation
# No GitHub repo, no Streamlit Cloud auto-deploy workflow.
#
# ### Real-World Example
# Push commit to `main` -> Streamlit Cloud detects change -> rebuild starts automatically.
#
# ### Best Practices
# - Add clear README.
# - Use releases/tags for milestone versions.
# - Keep sensitive files out of repository.
#
# ### Common Mistakes
# - Committing `.streamlit/secrets.toml`.
# - Publicly exposing keys in notebooks.

# %%
from pathlib import Path

root = Path.cwd()
if not (root / "README.md").exists() and (root.parent / "README.md").exists():
    root = root.parent

required_files = ["README.md", "app.py", "pyproject.toml", ".gitignore"]
report = {file: (root / file).exists() for file in required_files}
report
# Out:
# {'README.md': True, 'app.py': True, 'pyproject.toml': True, '.gitignore': True}
