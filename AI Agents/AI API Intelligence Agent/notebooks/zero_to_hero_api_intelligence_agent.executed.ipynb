# %% [markdown]
# # Zero-to-Hero: Production-Grade AI API Intelligence Agent
#
# This notebook explains REST APIs, authentication, async orchestration, LangGraph agents, tool calling, memory, caching, monitoring, and error handling.

# %% [markdown]
# ## 1. REST APIs and Authentication
#
# We use API keys and bearer tokens from environment variables. No credentials are hardcoded.

# %%
from api_intel_agent.auth import AuthManager
auth = AuthManager()
auth.auth_headers('github')
# Out:
# AuthHeaders(headers={}, status='no_auth_required')

# %% [markdown]
# ## 2. Async Requests and API Orchestration
#
# Data fetch agent executes API calls concurrently with retry and exponential backoff.

# %%
from api_intel_agent.connectors import ConnectorRegistry
registry = ConnectorRegistry()
await registry.get('jsonplaceholder').execute('test')
# Out:
# ConnectorResult(provider='jsonplaceholder', endpoint='/posts', status='failed', records=[], pagination={'attempts': 1}, latency_ms=0.0, cached=False, error=ErrorRecord(code='UNHANDLED_CONNECTOR_ERROR', message="Request URL is missing an 'http://' or 'https://' protocol.", provider='jsonplaceholder', retryable=True))

# %% [markdown]
# ## 3. LangGraph Multi-Agent Workflow
#
# The workflow has planner, router, authentication, fetch, validation, reasoning, report, memory, reflection.

# %%
from api_intel_agent.agents import AgentRunner
runner = AgentRunner()
runner
# Out:
# /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/AI Agents/AI API Intelligence Agent/src/api_intel_agent/monitoring/metrics.py:13: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   from pynvml import (

# %% [markdown]
# ## 4. Tool Calling
#
# Tools include calculator, HTTP client, file IO, markdown, CSV/JSON/PDF export, charts, search, datetime, and unit conversion.

# %%
from api_intel_agent.tools.factory import build_tool_registry
tools = build_tool_registry()
await tools.run('calculator', expression='2 + 2 * 10')
# Out:
# ToolResult(name='calculator', success=True, payload={'result': 22}, error=None)

# %% [markdown]
# ## 5. Memory and Caching
#
# SQLite stores full analysis history. ChromaDB adds semantic retrieval. SQLite/Redis cache reduces repeated API calls.

# %%
from api_intel_agent.memory import MemoryManager
memory = MemoryManager()
memory.history(limit=3)
# Out:
# [QueryHistoryItem(run_id='2325de8f-dda3-4e2a-8149-53796dcae839', query='Summarize AI news and compare with GitHub repos', status=<RunStatus.PARTIAL: 'partial'>, created_at=datetime.datetime(2026, 6, 30, 13, 44, 10, 202018, tzinfo=datetime.timezone.utc)),
#  QueryHistoryItem(run_id='311331b8-7064-4f5b-a804-9197b1d44630', query='Summarize AI news and compare with GitHub repos', status=<RunStatus.PARTIAL: 'partial'>, created_at=datetime.datetime(2026, 6, 30, 13, 42, 5, 719757, tzinfo=datetime.timezone.utc))]

# %% [markdown]
# ## 6. Monitoring and Error Handling
#
# We track CPU, memory, optional GPU/VRAM, cache hit rate, and per-provider latency.

# %%
from api_intel_agent.monitoring import MetricsCollector
MetricsCollector().snapshot()
# Out:
# MetricsSnapshot(cpu_percent=14.6, memory_percent=35.5, gpu_name=None, gpu_vram_used_mb=None, gpu_vram_total_mb=None, cache_hit_rate=0.0, api_latency_ms={}, llm_latency_ms=None, tokens_per_sec=None)

# %% [markdown]
# ## 7. End-to-End Run
#
# Run a full analysis query, generate reports, then inspect outputs.

# %%
from api_intel_agent.core.schemas import AnalyzeRequest
request = AnalyzeRequest(query='Summarize AI news and compare with GitHub repos', apis=['news', 'github'])
response = await runner.analyze(request)
response
# Out:
# AnalyzeResponse(run_id='0f70a893-fdca-4224-a90c-bbfdf037923f', status=<RunStatus.PARTIAL: 'partial'>, summary='Data collected. Some connectors may have partial, missing auth, or offline LLM analysis.', insights=['No records available from selected APIs'], recommendations=['Review top-ranked sources and validate trend consistency across APIs', 'Enable credentials for skipped providers to increase confidence', 'Schedule recurring report for longitudinal trend tracking'], sources=[], charts=[ChartArtifact(title='API latency', kind='line', path='artifacts/charts/api_latency_20260630T145139Z.html')], artifacts={'markdown': 'artifacts/reports/report_0f70a893-fdca-4224-a90c-bbfdf037923f.md', 'html': 'artifacts/reports/report_0f70a893-fdca-4224-a90c-bbfdf037923f.html', 'pdf': 'artifacts/reports/report_0f70a893-fdca-4224-a90c-bbfdf037923f.pdf', 'json': 'artifacts/reports/report_0f70a893-fdca-4224-a90c-bbfdf037923f.json', 'csv': 'artifacts/reports/report_0f70a893-fdca-4224-a90c-bbfdf037923f.csv'}, telemetry={'memory_hits': [], 'completed_at': '2026-06-30T14:51:39.340759+00:00'}, errors=[ErrorRecord(code='UNHANDLED_CONNECTOR_ERROR', message="Request URL is missing an 'http://' or 'https://' protocol.", provider='news', retryable=True), ErrorRecord(code='UNHANDLED_CONNECTOR_ERROR', message="Request URL is missing an 'http://' or 'https://' protocol.", provider='github', retryable=True), ErrorRecord(code='UNHANDLED_CONNECTOR_ERROR', message="Request URL is missing an 'http://' or 'https://' protocol.", provider='news', retryable=True), ErrorRecord(code='UNHANDLED_CONNECTOR_ERROR', message="Request URL is missing an 'http://' or 'https://' protocol.", provider='github', retryable=True)])
