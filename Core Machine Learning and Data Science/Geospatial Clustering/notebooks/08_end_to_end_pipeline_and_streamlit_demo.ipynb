# %% [markdown]
# # 08 - End-to-End Pipeline and Streamlit Demo
#
# Execute the production pipeline and inspect generated reports/artifacts.

# %% [markdown]
# ## Definition
# Explain the concept in one sentence and why it matters in delivery analytics.
#
# ## Theory
# Describe the assumptions and algorithmic behavior at a practical level.
#
# ## Mathematical Intuition
# Show the formula or geometry intuition behind the method.
#
# ## Visual Explanation
# Use a chart/map to make the concept concrete.
#
# ## Code Explanation
# Walk through what each code block does and what inputs/outputs mean.
#
# ## Interpretation of Results
# Connect metrics and visuals to operational decisions.

# %%
from __future__ import annotations

import sys
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

if (Path.cwd() / "src").exists():
    PROJECT_ROOT = Path.cwd()
elif (Path.cwd().parent / "src").exists():
    PROJECT_ROOT = Path.cwd().parent
else:
    raise RuntimeError("Could not locate project root.")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering

# %%
from src.config import TRAIN_FILE_PATH
from src.data_loader import load_raw_data, load_and_clean_data, explain_dataset_fields

# %%
from src.pipeline import GeospatialClusteringPipeline

pipe = GeospatialClusteringPipeline(run_downstream_automl=True)
report = pipe.run()

print("Best algorithm:", report.best_algorithm)
print("Warnings:", report.warnings)
print("Business impact:")
print(report.business_impact)
print("Report files:")
for k, v in report.report_paths.items():
    print(f"- {k}: {v}")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [flaml.automl.logger: 06-24 20:24:31] {2375} INFO - task = regression
# [flaml.automl.logger: 06-24 20:24:31] {2386} INFO - Evaluation method: holdout
# [flaml.automl.logger: 06-24 20:24:31] {2489} INFO - Minimizing error metric: rmse
# [flaml.automl.logger: 06-24 20:24:31] {2606} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd']
# [flaml.automl.logger: 06-24 20:24:31] {2911} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 06-24 20:24:32] {3046} INFO - Estimated sufficient time budget=4680s. Estimated necessary time budget=33s.
# [flaml.automl.logger: 06-24 20:24:32] {3097} INFO -  at 0.5s,	estimator lgbm's best error=8.2673e+00,	best estimator lgbm's best error=8.2673e+00
# [flaml.automl.logger: 06-24 20:24:32] {2911} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 06-24 20:24:32] {3097} INFO -  at 0.7s,	estimator lgbm's best error=8.2673e+00,	best estimator lgbm's best error=8.2673e+00
# [flaml.automl.logger: 06-24 20:24:32] {2911} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 06-24 20:24:33] {3097} INFO -  at 1.3s,	estimator lgbm's best error=7.0244e+00,	best estimator lgbm's best error=7.0244e+00
# [flaml.automl.logger: 06-24 20:24:33] {2911} INFO - iteration 3, current learner sgd
# [flaml.automl.logger: 06-24 20:24:36] {3097} INFO -  at 4.3s,	estimator sgd's best error=6.0343e+00,	best estimator sgd's best error=6.0343e+00
# [flaml.automl.logger: 06-24 20:24:36] {2911} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 06-24 20:24:37] {3097} INFO -  at 5.2s,	estimator xgboost's best error=8.2673e+00,	best estimator sgd's best error=6.0343e+00
# [flaml.automl.logger: 06-24 20:24:37] {2911} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 06-24 20:24:39] {3097} INFO -  at 7.1s,	estimator lgbm's best error=4.9086e+00,	best estimator lgbm's best error=4.9086e+00
# [flaml.automl.logger: 06-24 20:24:39] {2911} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 06-24 20:24:40] {3097} INFO -  at 8.4s,	estimator xgboost's best error=8.2673e+00,	best estimator lgbm's best error=4.9086e+00
# [flaml.automl.logger: 06-24 20:24:40] {2911} INFO - iteration 7, current learner extra_tree
# [flaml.automl.logger: 06-24 20:24:40] {3097} INFO -  at 8.7s,	estimator extra_tree's best error=7.7326e+00,	best estimator lgbm's best error=4.9086e+00
# [flaml.automl.logger: 06-24 20:24:40] {2911} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 06-24 20:24:40] {3097} INFO -  at 8.8s,	estimator xgboost's best error=7.1980e+00,	best estimator lgbm's best error=4.9086e+00
# [flaml.automl.logger: 06-24 20:24:40] {2911} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 06-24 20:24:41] {3097} INFO -  at 9.5s,	estimator lgbm's best error=4.9086e+00,	best estimator lgbm's best error=4.9086e+00
# [flaml.automl.logger: 06-24 20:24:41] {2911} INFO - iteration 10, current learner extra_tree
# [flaml.automl.logger: 06-24 20:24:41] {3097} INFO -  at 9.7s,	estimator extra_tree's best error=7.6534e+00,	best estimator lgbm's best error=4.9086e+00
# [flaml.automl.logger: 06-24 20:24:41] {2911} INFO - iteration 11, current learner rf
# [flaml.automl.logger: 06-24 20:24:41] {3097} INFO -  at 10.0s,	estimator rf's best error=7.2717e+00,	best estimator lgbm's best error=4.9086e+00
# [flaml.automl.logger: 06-24 20:24:41] {2911} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 06-24 20:24:42] {3097} INFO -  at 10.4s,	estimator rf's best error=7.1718e+00,	best estimator lgbm's best error=4.9086e+00
# [flaml.automl.logger: 06-24 20:24:42] {2911} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 06-24 20:24:53] {3097} INFO -  at 22.0s,	estimator lgbm's best error=4.6575e+00,	best estimator lgbm's best error=4.6575e+00
# [flaml.automl.logger: 06-24 20:24:53] {2911} INFO - iteration 14, current learner sgd
# [flaml.automl.logger: 06-24 20:25:03] {3097} INFO -  at 31.9s,	estimator sgd's best error=6.0343e+00,	best estimator lgbm's best error=4.6575e+00
# [flaml.automl.logger: 06-24 20:25:04] {3359} INFO - retrain lgbm for 0.3s
# [flaml.automl.logger: 06-24 20:25:04] {3362} INFO - retrained model: LGBMRegressor(colsample_bytree=0.8871559629536413,
#               learning_rate=0.1292426830415275, max_bin=63,
#               min_child_samples=14, n_estimators=64, n_jobs=-1, num_leaves=4,
#               reg_alpha=0.02960826033957992, reg_lambda=0.023368135622249268,
#               verbose=-1)
# [flaml.automl.logger: 06-24 20:25:04] {2636} INFO - fit succeeded
# [flaml.automl.logger: 06-24 20:25:04] {2637} INFO - Time taken to find the best model: 22.02090334892273
# Processing:   0%|          | 0/25 [00:00<?, ?it/s]
# Processing:  20%|██        | 5/25 [00:00<00:01, 13.45it/s]
# Processing:  28%|██▊       | 7/25 [00:00<00:01, 11.32it/s]
# Processing:  36%|███▌      | 9/25 [00:00<00:01,  8.42it/s]
# Processing:  44%|████▍     | 11/25 [00:01<00:01,  9.37it/s]
# Processing:  52%|█████▏    | 13/25 [00:08<00:14,  1.18s/it]
# Processing:  60%|██████    | 15/25 [00:08<00:08,  1.20it/s]
# Processing:  68%|██████▊   | 17/25 [00:12<00:09,  1.21s/it]
# Processing:  76%|███████▌  | 19/25 [00:12<00:05,  1.16it/s]
# Processing:  84%|████████▍ | 21/25 [00:13<00:02,  1.46it/s]
# Processing:  92%|█████████▏| 23/25 [00:13<00:00,  2.01it/s]
# Processing: 100%|██████████| 25/25 [00:15<00:00,  1.50it/s]
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  3.2992  17.1699  4.1423  0.7834
# rf                Random Forest Regressor  3.3939  17.9484  4.2354  0.7735
# lightgbm  Light Gradient Boosting Machine  3.4074  17.9706  4.2381  0.7732
# ridge                    Ridge Regression  4.7301  35.0345  5.9188  0.5573
# lr                      Linear Regression  4.7333  35.1758  5.9308  0.5555
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1686  0.1425    1.3600
# rf        0.1713  0.1460    2.3133
# lightgbm  0.1718  0.1465    0.1933
# ridge     0.2400  0.2079    0.1167
# lr        0.2403  0.2080    0.1200
# Best algorithm: hdbscan
# Warnings: []
# Business impact:
# {'avg_delivery_distance_km': 9.627877886135236, 'p90_delivery_distance_km': 17.10331819387933, 'cluster_count': 241.0, 'noise_point_pct': 0.6440889258258882, 'outlier_pct': 0.0, 'coverage_pct': 100.0, 'silhouette': 0.08170813314862942, 'davies_bouldin': 20.760859896857372, 'calinski_harabasz': 258362.64502200607, 'stability_ari': 1.0, 'composite_score': 3.78277369188774, 'original_outlier_pct': 3.756842552553303, 'downstream_best_rmse': 3.874171004172512, 'downstream_best_model': 'RandomForestRegressor'}
# Report files:
# - dataset_profile: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/outputs/reports/dataset_profile.json
# - geospatial_validation: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/outputs/reports/geospatial_validation.json
# - clustering_metrics: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/outputs/reports/clustering_evaluation.csv
# - k_selection_diagnostics: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/outputs/reports/k_selection_diagnostics.csv
# - zone_kpis: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/outputs/reports/business_zone_kpis.csv
# - assignments: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/data/processed/cluster_assignments.csv
# - zone_rule_summary: {"high_demand_threshold": 154.0, "low_activity_threshold": 143.0, "high_density_threshold": 15.779060305569226, "centrality_threshold_km": 497.33508069105375, "southern_lat_threshold": 12.979477}
# - spatial_coverage: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/outputs/reports/spatial_density_summary.csv
# - kde_hotspots: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/outputs/reports/kde_hotspots.csv
# - grid_density: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/outputs/reports/grid_density.csv
# - downstream_benchmark: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering/outputs/reports/downstream_benchmark.csv

# %% [markdown]
# ## Streamlit Demo
#
# Launch locally:
# ```bash
# uv run streamlit run streamlit_app/app.py
# ```
