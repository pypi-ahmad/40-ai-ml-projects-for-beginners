# %% [markdown]
# # 07 - Downstream AutoML Benchmark
#
# Benchmark manual ML vs LazyPredict vs PyCaret vs FLAML for delivery-time prediction.

# %% [markdown]
# ## Definition
# Explain the concept in one sentence and why it matters in delivery analytics.
#
# ## Theory
# Describe the assumptions and algorithmic behavior at a practical level.
#
# ## Mathematical Intuition
# Show the formula or geometry intuition behind the method.
#
# ## Visual Explanation
# Use a chart/map to make the concept concrete.
#
# ## Code Explanation
# Walk through what each code block does and what inputs/outputs mean.
#
# ## Interpretation of Results
# Connect metrics and visuals to operational decisions.

# %%
from __future__ import annotations

import sys
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

if (Path.cwd() / "src").exists():
    PROJECT_ROOT = Path.cwd()
elif (Path.cwd().parent / "src").exists():
    PROJECT_ROOT = Path.cwd().parent
else:
    raise RuntimeError("Could not locate project root.")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: /home/ahmad/AI/Github/40 AI-ML Projects for Beginners/Core Machine Learning and Data Science/Geospatial Clustering

# %%
from src.config import TRAIN_FILE_PATH
from src.data_loader import load_raw_data, load_and_clean_data, explain_dataset_fields

# %%
from src.features import build_downstream_features
from src.downstream_benchmark import run_full_benchmark

df = load_and_clean_data(TRAIN_FILE_PATH)
feat = build_downstream_features(df.copy())
bench = run_full_benchmark(feat)
display(bench.sort_values(["status", "rmse"]))
# Out:
# [flaml.automl.logger: 06-24 20:14:40] {2375} INFO - task = regression
# [flaml.automl.logger: 06-24 20:14:40] {2386} INFO - Evaluation method: holdout
# [flaml.automl.logger: 06-24 20:14:40] {2489} INFO - Minimizing error metric: rmse
# [flaml.automl.logger: 06-24 20:14:40] {2606} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd']
# [flaml.automl.logger: 06-24 20:14:40] {2911} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 06-24 20:14:41] {3046} INFO - Estimated sufficient time budget=9826s. Estimated necessary time budget=70s.
# [flaml.automl.logger: 06-24 20:14:41] {3097} INFO -  at 1.0s,	estimator lgbm's best error=8.2462e+00,	best estimator lgbm's best error=8.2462e+00
# [flaml.automl.logger: 06-24 20:14:41] {2911} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 06-24 20:14:42] {3097} INFO -  at 2.0s,	estimator lgbm's best error=8.2462e+00,	best estimator lgbm's best error=8.2462e+00
# [flaml.automl.logger: 06-24 20:14:42] {2911} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 06-24 20:14:44] {3097} INFO -  at 3.7s,	estimator lgbm's best error=6.9982e+00,	best estimator lgbm's best error=6.9982e+00
# [flaml.automl.logger: 06-24 20:14:44] {2911} INFO - iteration 3, current learner sgd
# [flaml.automl.logger: 06-24 20:14:47] {3097} INFO -  at 7.3s,	estimator sgd's best error=5.9702e+00,	best estimator sgd's best error=5.9702e+00
# [flaml.automl.logger: 06-24 20:14:47] {2911} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 06-24 20:14:48] {3097} INFO -  at 8.3s,	estimator xgboost's best error=8.2462e+00,	best estimator sgd's best error=5.9702e+00
# [flaml.automl.logger: 06-24 20:14:48] {2911} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 06-24 20:14:52] {3097} INFO -  at 11.6s,	estimator lgbm's best error=4.8691e+00,	best estimator lgbm's best error=4.8691e+00
# [flaml.automl.logger: 06-24 20:14:52] {2911} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 06-24 20:14:52] {3097} INFO -  at 12.4s,	estimator xgboost's best error=8.2462e+00,	best estimator lgbm's best error=4.8691e+00
# [flaml.automl.logger: 06-24 20:14:52] {2911} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 06-24 20:14:54] {3097} INFO -  at 13.7s,	estimator lgbm's best error=4.8691e+00,	best estimator lgbm's best error=4.8691e+00
# [flaml.automl.logger: 06-24 20:14:54] {2911} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 06-24 20:15:01] {3097} INFO -  at 21.0s,	estimator lgbm's best error=4.6222e+00,	best estimator lgbm's best error=4.6222e+00
# [flaml.automl.logger: 06-24 20:15:01] {2911} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 06-24 20:15:01] {3097} INFO -  at 21.2s,	estimator xgboost's best error=7.1310e+00,	best estimator lgbm's best error=4.6222e+00
# [flaml.automl.logger: 06-24 20:15:01] {2911} INFO - iteration 10, current learner extra_tree
# [flaml.automl.logger: 06-24 20:15:01] {3097} INFO -  at 21.4s,	estimator extra_tree's best error=7.6486e+00,	best estimator lgbm's best error=4.6222e+00
# [flaml.automl.logger: 06-24 20:15:01] {2911} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 06-24 20:15:02] {3097} INFO -  at 21.6s,	estimator extra_tree's best error=7.6266e+00,	best estimator lgbm's best error=4.6222e+00
# [flaml.automl.logger: 06-24 20:15:02] {2911} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 06-24 20:15:02] {3097} INFO -  at 21.9s,	estimator rf's best error=7.5016e+00,	best estimator lgbm's best error=4.6222e+00
# [flaml.automl.logger: 06-24 20:15:02] {2911} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 06-24 20:15:02] {3097} INFO -  at 22.2s,	estimator rf's best error=7.2405e+00,	best estimator lgbm's best error=4.6222e+00
# [flaml.automl.logger: 06-24 20:15:02] {2911} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 06-24 20:15:03] {3097} INFO -  at 23.2s,	estimator xgboost's best error=7.1310e+00,	best estimator lgbm's best error=4.6222e+00
# [flaml.automl.logger: 06-24 20:15:03] {2911} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 06-24 20:15:04] {3097} INFO -  at 24.3s,	estimator xgboost's best error=4.6078e+00,	best estimator xgboost's best error=4.6078e+00
# [flaml.automl.logger: 06-24 20:15:04] {2911} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 06-24 20:15:05] {3097} INFO -  at 25.1s,	estimator xgboost's best error=4.6078e+00,	best estimator xgboost's best error=4.6078e+00
# [flaml.automl.logger: 06-24 20:15:05] {2911} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 06-24 20:15:09] {3097} INFO -  at 29.1s,	estimator xgboost's best error=4.2174e+00,	best estimator xgboost's best error=4.2174e+00
# [flaml.automl.logger: 06-24 20:15:09] {2911} INFO - iteration 18, current learner rf
# [flaml.automl.logger: 06-24 20:15:09] {3097} INFO -  at 29.4s,	estimator rf's best error=6.3974e+00,	best estimator xgboost's best error=4.2174e+00
# [flaml.automl.logger: 06-24 20:15:09] {2911} INFO - iteration 19, current learner rf
# [flaml.automl.logger: 06-24 20:15:10] {3097} INFO -  at 29.8s,	estimator rf's best error=5.7169e+00,	best estimator xgboost's best error=4.2174e+00
# [flaml.automl.logger: 06-24 20:15:10] {2911} INFO - iteration 20, current learner xgb_limitdepth
# [flaml.automl.logger: 06-24 20:15:10] {3097} INFO -  at 30.1s,	estimator xgb_limitdepth's best error=7.5748e+00,	best estimator xgboost's best error=4.2174e+00
# [flaml.automl.logger: 06-24 20:15:13] {3359} INFO - retrain xgboost for 2.4s
# [flaml.automl.logger: 06-24 20:15:13] {3362} INFO - retrained model: XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=0.9919147257144936, colsample_bynode=None,
#              colsample_bytree=0.9549891298248687, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints=None, learning_rate=0.5500317092437325,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=0, max_leaves=28,
#              min_child_weight=0.9030514379170209, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=16,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 06-24 20:15:13] {2636} INFO - fit succeeded
# [flaml.automl.logger: 06-24 20:15:13] {2637} INFO - Time taken to find the best model: 29.136053562164307
# Processing:   0%|          | 0/25 [00:00<?, ?it/s]
# Processing:  20%|██        | 5/25 [00:00<00:01, 12.88it/s]
# Processing:  28%|██▊       | 7/25 [00:00<00:01, 11.62it/s]
# Processing:  36%|███▌      | 9/25 [00:00<00:01,  8.35it/s]
# Processing:  44%|████▍     | 11/25 [00:01<00:01,  9.74it/s]
# Processing:  52%|█████▏    | 13/25 [00:08<00:14,  1.21s/it]
# Processing:  60%|██████    | 15/25 [00:08<00:08,  1.18it/s]
# Processing:  68%|██████▊   | 17/25 [00:12<00:09,  1.23s/it]
# Processing:  76%|███████▌  | 19/25 [00:12<00:05,  1.15it/s]
# Processing:  84%|████████▍ | 21/25 [00:13<00:02,  1.44it/s]
# Processing:  92%|█████████▏| 23/25 [00:13<00:01,  2.00it/s]
# Processing: 100%|██████████| 25/25 [00:15<00:00,  1.49it/s]
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  3.3645  18.2085  4.2666  0.7918
# lightgbm  Light Gradient Boosting Machine  3.4167  18.5672  4.3083  0.7877
# rf                Random Forest Regressor  3.4503  19.2479  4.3867  0.7801
# ridge                    Ridge Regression  4.7759  36.5320  6.0428  0.5828
# lr                      Linear Regression  4.7896  36.7984  6.0649  0.5796
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1752  0.1470    1.3933
# lightgbm  0.1754  0.1477    0.1933
# rf        0.1771  0.1489    2.3833
# ridge     0.2449  0.2105    0.1233
# lr        0.2462  0.2110    0.1267
#       framework                  model      rmse       mae        r2  \
# 2        manual  RandomForestRegressor  3.884043  3.098120  0.830442
# 11        flaml                xgboost  3.901492  3.130016  0.828915
# 12      pycaret  Extra Trees Regressor  4.103253  3.252561  0.810763
# 3   lazypredict    ExtraTreesRegressor  4.438725       NaN  0.781031
# 4   lazypredict       BaggingRegressor  4.569323       NaN  0.767956
# 5   lazypredict      AdaBoostRegressor  5.160194       NaN  0.704064
# 6   lazypredict  DecisionTreeRegressor  5.719411       NaN  0.636446
# 7   lazypredict          BayesianRidge  5.782822       NaN  0.628340
# 8   lazypredict           ElasticNetCV  5.807454       NaN  0.625167
# 1        manual       LinearRegression  5.952328  4.742299  0.601779
# 9   lazypredict         GammaRegressor  6.305778       NaN  0.558080
# 10  lazypredict     ExtraTreeRegressor  6.390227       NaN  0.546164
# 0        manual         DummyRegressor  9.433899  7.668621 -0.000306
#
#     runtime_sec status                                               note
# 2      8.412529     ok
# 11    32.614402     ok  best_config={'n_estimators': 16, 'max_leaves':...
# 12    17.577213     ok
# 3      7.464285     ok
# 4      7.464285     ok
# 5      7.464285     ok
# 6      7.464285     ok
# 7      7.464285     ok
# 8      7.464285     ok
# 1      1.175017     ok
# 9      7.464285     ok
# 10     7.464285     ok
# 0      0.730090     ok
